# %% [markdown]
# # Análise Arquiteturas Timeloop

# %%
import csv

with open('dse_pe_mac_width/dse_results.csv', mode='r', newline='') as csvfile:
    # Create a reader object (default delimiter is comma)
    #csv_reader = csv.reader(csvfile)
    csv_reader = csv.DictReader(csvfile)
    
    # Optional: Skip the header row if present
    # next(csv_reader, None) 
    
    # Iterate over each row
    for row in csv_reader:
        print(row)
# Out:
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_2_macs_4_width;100.0;4480;2240;1e-09;2.24e-06;8.6297618e-08;1.7190521599999998e-08;2000000000.0;2.3175610710367464e+16;260608729871.23325;;{'MACC': 1.0051775999999999e-09", None: [" 'Input_Port': 2.08768e-11", " 'GlobalBuffer': 1.61644672e-08", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 8.60227e-08", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 2.67938e-10};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_2_macs_6_width;100.0;4480;2240;1e-09;2.24e-06;1.2959171399999998e-07;2.27114496e-08;2000000000.0;1.543308548261041e+16;197257334027.67917;;{'MACC': 2.1735168000000004e-09", None: [" 'Input_Port': 2.08768e-11", " 'GlobalBuffer': 2.0517056e-08", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 1.29034e-07", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 5.507340000000001e-10};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_2_macs_16_width;100.0;4480;2240;1e-09;2.24e-06;3.5842998e-07;5.6476448e-08;2000000000.0;5579890387517250.0;79325102031.91249;;{'MACC': 1.4672e-08", None: [" 'Input_Port': 2.08768e-11", " 'GlobalBuffer': 4.17835712e-08", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 3.5497e-07", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 3.453e-09};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_4_macs_4_width;100.0;4480;1120;1e-09;1.12e-06;1.72587856e-07;7.529312000000001e-09;4000000000.0;2.317660171872116e+16;595007883854.4609;;{'MACC': 1.0051775999999999e-09", None: [" 'Input_Port': 1.04384e-11", " 'GlobalBuffer': 6.513696e-09", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 1.72045e-07", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 5.35876e-10};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_4_macs_6_width;100.0;4480;1120;1e-09;1.12e-06;2.67571448e-07;1.00715328e-08;4000000000.0;1.4949278145701106e+16;444818091641.4232;;{'MACC': 2.1735168000000004e-09", None: [" 'Input_Port': 1.04384e-11", " 'GlobalBuffer': 7.8875776e-09", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 2.66463e-07", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 1.1014680000000001e-09};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_4_macs_16_width;100.0;4480;1120;1e-09;1.12e-06;7.4095598e-07;4.0650848e-08;4000000000.0;5398431361603965.0;110206803065.95326;;{'MACC': 1.4672e-08", None: [" 'Input_Port': 1.04384e-11", " 'GlobalBuffer': 2.5968409600000003e-08", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 7.34043e-07", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 6.906e-09};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_8_macs_4_width;87.5;4480;640;1e-09;6.4e-07;3.56048732e-07;3.2347391999999997e-09;7000000000.0;1.966023010580473e+16;1384964821893.524;;{'MACC': 1.0051775999999999e-09", None: [" 'Input_Port': 1.008e-11", " 'GlobalBuffer': 2.2194816e-09", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 3.5497e-07", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 1.071752e-09};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_8_macs_6_width;87.5;4480;640;1e-09;6.4e-07;5.41705916e-07;5.802182400000001e-09;7000000000.0;1.2922140580794396e+16;772123261757.5068;;{'MACC': 2.1735168000000004e-09", None: [" 'Input_Port': 1.008e-11", " 'GlobalBuffer': 3.6185856000000003e-09", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 5.39496e-07", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 2.2029360000000002e-09};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "1_neurons_8_macs_16_width;87.5;4480;640;1e-09;6.4e-07;1.52860898e-06;2.6332096e-08;7000000000.0;4579326754969083.0;170134576449.97192;;{'MACC': 1.4672e-08", None: [" 'Input_Port': 1.008e-11", " 'GlobalBuffer': 1.1650016e-08", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 1.51479e-06", " 'Input_Port': 5.980000000000001e-12", " 'inter_MACC_spatial': 1e-12", " 'MACC': 1.3812e-08};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "2_neurons_2_macs_4_width;50.0;4480;2240;1e-09;2.24e-06;1.72595836e-07;1.34715392e-08;2000000000.0;1.1587765072153884e+16;332552942428.43463;;{'MACC': 1.0051775999999999e-09", None: [" 'Input_Port': 2.08768e-11", " 'GlobalBuffer': 1.24454848e-08", " 'inter_PE_Array_spatial': 0", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 1.72045e-07", " 'inter_PE_Array_spatial': 1e-12", " 'Input_Port': 1.1960000000000002e-11", " 'inter_MACC_spatial': 2e-12", " 'MACC': 5.35876e-10};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "2_neurons_2_macs_6_width;50.0;4480;2240;1e-09;2.24e-06;2.67579428e-07;1.7303552e-08;2000000000.0;7474416157283960.0;258906379453.18973;;{'MACC': 2.1735168000000004e-09", None: [" 'Input_Port': 2.08768e-11", " 'GlobalBuffer': 1.51091584e-08", " 'inter_PE_Array_spatial': 0", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 2.66463e-07", " 'inter_PE_Array_spatial': 1e-12", " 'Input_Port': 1.1960000000000002e-11", " 'inter_MACC_spatial': 2e-12", " 'MACC': 1.1014680000000001e-09};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "2_neurons_2_macs_16_width;50.0;4480;2240;1e-09;2.24e-06;7.4096396e-07;6.44645568e-08;2000000000.0;2699186610911548.0;69495552632.1093;;{'MACC': 1.4672e-08", None: [" 'Input_Port': 2.08768e-11", " 'GlobalBuffer': 4.977168e-08", " 'inter_PE_Array_spatial': 0", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 7.34043e-07", " 'inter_PE_Array_spatial': 1e-12", " 'Input_Port': 1.1960000000000002e-11", " 'inter_MACC_spatial': 2e-12", " 'MACC': 6.906e-09};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "2_neurons
Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "16_neurons_4_macs_6_width;43.75;4480;160;1e-09;1.6e-07;5.442326168e-06;2.2878016e-08;28000000000.0;5144858859183319.0;195821176101.98367;;{'MACC': 2.1735168000000004e-09", None: [" 'Input_Port': 1.21856e-11", " 'GlobalBuffer': 2.0692313599999998e-08", " 'inter_PE_Array_spatial': 0", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 5.42459e-06", " 'inter_PE_Array_spatial': 1e-12", " 'Input_Port': 9.568000000000001e-11", " 'inter_MACC_spatial': 1.6e-11", " 'MACC': 1.7623488000000002e-08};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "16_neurons_4_macs_16_width;43.75;4480;160;1e-09;1.6e-07;1.869480868e-05;1.1969175679999999e-07;28000000000.0;1497741992404278.5;37429478184.415794;;{'MACC': 1.4672e-08", None: [" 'Input_Port': 1.21856e-11", " 'GlobalBuffer': 1.0500757119999999e-07", " 'inter_PE_Array_spatial': 0", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 1.85842e-05", " 'inter_PE_Array_spatial': 1e-12", " 'Input_Port': 9.568000000000001e-11", " 'inter_MACC_spatial': 1.6e-11", " 'MACC': 1.10496e-07};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "16_neurons_8_macs_4_width;27.34;4480;128;1e-09;1.28e-07;7.635180712e-06;5.664735999999999e-09;35000000000.0;4584043432657917.0;790857685159.5557;;{'MACC': 1.0051775999999999e-09", None: [" 'Input_Port': 1.01248e-11", " 'GlobalBuffer': 4.649433599999999e-09", " 'inter_PE_Array_spatial': 0", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 7.61792e-06", " 'inter_PE_Array_spatial': 1e-12", " 'Input_Port': 9.568000000000001e-11", " 'inter_MACC_spatial': 1.6e-11", " 'MACC': 1.7148032e-08};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "16_neurons_8_macs_6_width;27.34;4480;128;1e-09;1.28e-07;1.2646659656e-05;1.06611008e-08;35000000000.0;2767529209453725.0;420219270415.30273;;{'MACC': 2.1735168000000004e-09", None: [" 'Input_Port': 1.01248e-11", " 'GlobalBuffer': 8.4774592e-09", " 'inter_PE_Array_spatial': 0", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 1.26113e-05", " 'inter_PE_Array_spatial': 1e-12", " 'Input_Port': 9.568000000000001e-11", " 'inter_MACC_spatial': 1.6e-11", " 'MACC': 3.5246976000000003e-08};Specification[variables].Variables={'version': '0.4'}"]}
# {'arquitecture;percent_utilization;computes;cycles;cycle_seconds;latency;area;energy;computes_per_second;computes_per_second_per_square_meter;computes_per_joule;acesses;per_component_energy;per_component_area;variables': "16_neurons_8_macs_16_width;27.34;4480;128;1e-09;1.28e-07;4.687020468e-05;5.2100384e-08;35000000000.0;746743058601040.4;85987849916.80676;;{'MACC': 1.4672e-08", None: [" 'Input_Port': 1.01248e-11", " 'GlobalBuffer': 3.74182592e-08", " 'inter_PE_Array_spatial': 0", " 'inter_MACC_spatial': 0};{'GlobalBuffer': 4.66491e-05", " 'inter_PE_Array_spatial': 1e-12", " 'Input_Port': 9.568000000000001e-11", " 'inter_MACC_spatial': 1.6e-11", " 'MACC': 2.20992e-07};Specification[variables].Variables={'version': '0.4'}"]}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Carregar os dados corretamente
file_path = 'dse_pe_mac_width/dse_results.csv'
try:
    df = pd.read_csv(file_path, sep=';', engine='python', on_bad_lines='skip')
except:
    print("Erro na leitura. Verifique o caminho do arquivo.")

# 2. Converter colunas para numérico (incluindo 'area')
cols_to_convert = ['cycles', 'energy', 'area']
for col in cols_to_convert:
    df[col] = pd.to_numeric(df[col], errors='coerce')

    
df['num_macs'] = df['arquitecture'].str.split('_').str[2].astype(int)
df['num_neurons'] = df['arquitecture'].str.split('_').str[0].astype(int)

# 3. Criar o Gráfico
plt.figure(figsize=(10, 10))

sns.scatterplot(
    data=df, 
    x='cycles', 
    y='energy', 
    hue='num_macs',   # Cores diferentes para cada arquitetura
    style='num_neurons', # Símbolos diferentes (ajuda se tiver muitas cores parecidas)
    size='area',          # <--- AQUI: Define o tamanho baseado na coluna 'area'
    sizes=(100, 400),      # (Min, Max): O menor ponto terá tamanho 50, o maior 400
    alpha=0.7,            # Transparência para ver pontos sobrepostos
    palette='viridis'     # Uma paleta de cores agradável
    
)


plt.title('Trade-off: Cycles vs Energy (Tamanho do ponto = Area)')
plt.xlabel('Cycles (s)')
plt.ylabel('Energy (J)')

# Move a legenda para fora para não cobrir os dados
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
